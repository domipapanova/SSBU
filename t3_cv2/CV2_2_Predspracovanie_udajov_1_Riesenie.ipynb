# %% [markdown]
# # (Pred)spracovanie a analýza údajov
#
# ## Rozumieť údajom
#
# - predpracovanie je jedna z najdôležitejších častí
#
# - iba keď máte o vašich dátach predstavu, budete ich vedieť správne spracovať a vyhodnotiť
#
# ### 6 fáz:
#
# - Objavovanie (explore)
# - Očistenie (clean)
# - Úpravy (mutate)
# - Popis (describe)
# - Vizualizácia (vizualize)
# - Analýza (analyze)

# %%
# R
# install and load necessary libraries

install.packages("tidyverse")
install.packages("ggplot2")
install.packages("data.table")
install.packages("corrplot")

library(tidyverse)
# Out:
# Warning message:
# "package 'tidyverse' is in use and will not be installed"
# Warning message:
# "package 'ggplot2' is in use and will not be installed"
# Installing package into 'C:/Users/domin/AppData/Local/R/win-library/4.3'
# (as 'lib' is unspecified)
# package 'data.table' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\domin\AppData\Local\Temp\RtmpUVhUBA\downloaded_packages
# Installing package into 'C:/Users/domin/AppData/Local/R/win-library/4.3'
# (as 'lib' is unspecified)
# package 'corrplot' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\domin\AppData\Local\Temp\RtmpUVhUBA\downloaded_packages

# %% [markdown]
# ## Objavovanie (explore)
#
# Budeme používať dataset U.S. Chronic Disease Indicators (CDI), dostupný na:
# - https://catalog.data.gov/dataset/u-s-chronic-disease-indicators-cdi
#
# 1. načítanie datasetu - aby sme nemuseli dataset manuálne sťahovať, použijeme vstavané funkcie R pre stiahnutie a načítanie súboru

# %%
# URL to download the dataset
dataset_url <- "https://data.cdc.gov/api/views/g4ie-h725/rows.csv?accessType=DOWNLOAD"

# destination file path
dest_file <- "D:/UNIZA/ING/LETNY PRVAK/SSBU/data.csv" # TODO - fill in

# download the dataset
#download.file(dataset_url, destfile = dest_file)

# read the CSV file into R
data <- read.csv(dest_file)

# %% [markdown]
# 2. Zobrazenie základých informácií o datasete
#
#    (Pri dlhých výstupoch je dobré zapnúť posuvný mód - klik pravým tlačidlom myši na Output a výber 'Enable Scrolling for Outputs')

# %%
# glimpse shows variables, variable type and first values
glimpse(data)
# Out:
# Rows: 1,032,049
# Columns: 34
# $ YearStart                 <int> 2014, 2018, 2018, 2017, 2010, 2015, 2013, 20…
# $ YearEnd                   <int> 2014, 2018, 2018, 2017, 2010, 2015, 2013, 20…
# $ LocationAbbr              <chr> "AR", "CO", "DC", "GA", "MI", "MT", "OR", "P…
# $ LocationDesc              <chr> "Arkansas", "Colorado", "District of Columbi…
# $ DataSource                <chr> "SEDD; SID", "SEDD; SID", "SEDD; SID", "SEDD…
# $ Topic                     <chr> "Asthma", "Asthma", "Asthma", "Asthma", "Ast…
# $ Question                  <chr> "Hospitalizations for asthma", "Hospitalizat…
# $ Response                  <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ DataValueUnit             <chr> "", "", "", "", "", "", "", "", "", "", "", …
# $ DataValueType             <chr> "Number", "Number", "Number", "Number", "Num…
# $ DataValue                 <chr> "916", "2227", "708", "3520", "123", "", "76…
# $ DataValueAlt              <dbl> 916, 2227, 708, 3520, 123, NA, 760, NA, NA, …
# $ DataValueFootnoteSymbol   <chr> "", "", "", "", "", "-", "", "-", "-", "", "…
# $ DatavalueFootnote         <chr> "", "", "", "", "", "No data available", "",…
# $ LowConfidenceLimit        <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ HighConfidenceLimit       <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ StratificationCategory1   <chr> "Gender", "Overall", "Overall", "Gender", "R…
# $ Stratification1           <chr> "Male", "Overall", "Overall", "Female", "His…
# $ StratificationCategory2   <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ Stratification2           <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ StratificationCategory3   <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ Stratification3           <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ GeoLocation               <chr> "POINT (-92.27449074299966 34.74865012400045…
# $ ResponseID                <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ LocationID                <int> 5, 8, 11, 13, 26, 30, 41, 72, 72, 55, 55, 1,…
# $ TopicID                   <chr> "AST", "AST", "AST", "AST", "AST", "AST", "A…
# $ QuestionID                <chr> "AST3_1", "AST3_1", "AST3_1", "AST3_1", "AST…
# $ DataValueTypeID           <chr> "NMBR", "NMBR", "NMBR", "NMBR", "NMBR", "NMB…
# $ StratificationCategoryID1 <chr> "GENDER", "OVERALL", "OVERALL", "GENDER", "R…
# $ StratificationID1         <chr> "GENM", "OVR", "OVR", "GENF", "HIS", "HIS", …
# $ StratificationCategoryID2 <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ StratificationID2         <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ StratificationCategoryID3 <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …
# $ StratificationID3         <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, …

# %%
# view - similar to glimpse, but formatted
# !! doesn't display all the variables, if there are too many
View(data)
# Out:
#         YearStart YearEnd LocationAbbr LocationDesc         DataSource
# 1       2014      2014    AR           Arkansas             SEDD; SID
# 2       2018      2018    CO           Colorado             SEDD; SID
# 3       2018      2018    DC           District of Columbia SEDD; SID
# 4       2017      2017    GA           Georgia              SEDD; SID
# 5       2010      2010    MI           Michigan             SEDD; SID
# 6       2015      2015    MT           Montana              SEDD; SID
# 7       2013      2013    OR           Oregon               SEDD; SID
# 8       2013      2013    PR           Puerto Rico          SEDD; SID
# 9       2017      2017    PR           Puerto Rico          SEDD; SID
# 10      2010      2010    WI           Wisconsin            SEDD; SID
# 11      2016      2016    WI           Wisconsin            SEDD; SID
# 12      2014      2014    AL           Alabama              NVSS
# 13      2015      2015    ID           Idaho                NVSS
# 14      2016      2016    ID           Idaho                NVSS
# 15      2020      2020    IL           Illinois             NVSS
# 16      2012      2012    KS           Kansas               NVSS
# 17      2015      2015    KS           Kansas               NVSS
# 18      2018      2018    KS           Kansas               NVSS
# 19      2017      2017    LA           Louisiana            NVSS
# 20      2017      2017    MA           Massachusetts        NVSS
# 21      2010      2010    MD           Maryland             NVSS
# 22      2014      2014    MD           Maryland             NVSS
# 23      2010      2010    MN           Minnesota            NVSS
# 24      2019      2019    MS           Mississippi          NVSS
# 25      2014      2014    NC           North Carolina       NVSS
# 26      2020      2020    NM           New Mexico           NVSS
# 27      2010      2010    TX           Texas                NVSS
# 28      2011      2011    TX           Texas                NVSS
# 29      2016      2016    TX           Texas                NVSS
# 30      2008      2012    NY           New York             Death Certificate
# ⋮       ⋮         ⋮       ⋮            ⋮                    ⋮
# 1032020 2012      2012    RI           Rhode Island         BRFSS
# 1032021 2014      2014    RI           Rhode Island         BRFSS
# 1032022 2021      2021    RI           Rhode Island         BRFSS
# 1032023 2014      2014    RI           Rhode Island         BRFSS
# 1032024 2011      2011    RI           Rhode Island         BRFSS
# 1032025 2021      2021    SC           South Carolina       BRFSS
# 1032026 2014      2014    RI           Rhode Island         BRFSS
# 1032027 2020      2020    RI           Rhode Island         BRFSS
# 1032028 2016      2016    RI           Rhode Island         BRFSS
# 1032029 2012      2012    RI           Rhode Island         BRFSS
# 1032030 2013      2013    RI           Rhode Island         BRFSS
# 1032031 2018      2018    RI           Rhode Island         BRFSS
# 1032032 2016      2016    RI           Rhode Island         BRFSS
# 1032033 2019      2019    RI           Rhode Island         BRFSS
# 1032034 2020      2020    RI           Rhode Island         BRFSS
# 1032035 2015      2015    RI           Rhode Island         BRFSS
# 1032036 2020      2020    RI           Rhode Island         BRFSS
# 1032037 2013      2013    RI           Rhode Island         BRFSS
# 1032038 2020      2020    RI           Rhode Island         BRFSS
# 1032039 2016      2016    RI           Rhode Island         BRFSS
# 1032040 2017      2017    RI           Rhode Island         BRFSS
# 1032041 2016      2016    RI           Rhode Island         BRFSS
# 1032042 2021      2021    RI           Rhode Island         BRFSS
# 1032043 2012      2012    RI           Rhode Island         BRFSS
# 1032044 2019      2019    RI           Rhode Island         BRFSS
# 1032045 2012      2012    RI           Rhode Island         BRFSS
# 1032046 2019      2019    RI           Rhode Island         BRFSS
# 1032047 2016      2016    RI           Rhode Island         BRFSS
# 1032048 2015      2015    RI           Rhode Island         BRFSS
# 1032049 2014      2014    RI           Rhode Island         BRFSS
#         Topic
# 1       Asthma
# 2       Asthma
# 3       Asthma
# 4       Asthma
# 5       Asthma
# 6       Asthma
# 7       Asthma
# 8       Asthma
# 9       Asthma
# 10      Asthma
# 11      Asthma
# 12      Asthma
# 13      Asthma
# 14      Asthma
# 15      Asthma
# 16      Asthma
# 17      Asthma
# 18      Asthma
# 19      Asthma
# 20      Asthma
# 21      Asthma
# 22      Asthma
# 23      Asthma
# 24      Asthma
# 25      Asthma
# 26      Asthma
# 27      Asthma
# 28      Asthma
# 29      Asthma
# 30      Cancer
# ⋮       ⋮
# 1032020 Alcohol
# 1032021 Nutrition, Physical Activity, and Weight Status
# 1032022 Cardiovascular Disease
# 1032023 Diabetes
# 1032024 Reproductive Health
# 1032025 Chronic Kidney Disease
# 1032026 Nutrition, Physical Activity, and Weight Status
# 1032027 Diabetes
# 1032028 Asthma
# 1032029 Overarching Conditions
# 1032030 Nutrition, Physical Activity, and Weight Status
# 1032031 Cardiovascular Disease
# 1032032 Diabetes
# 1032033 Chronic Obstructive Pulmonary Disease
# 1032034 Oral Health
# 1032035 Tobacco
# 1032036 Diabetes
# 1032037 Asthma
# 1032038 Mental Health
# 1032039 Arthritis
# 1032040 Overarching Conditions
# 1032041 Diabetes
# 1032042 Cardiovascular Disease
# 1032043 Chronic Obstructive Pulmonary Disease
# 1032044 Overarching Conditions
# 1032045 Nutrition, Physical Activity, and Weight Status
# 1032046 Diabetes
# 1032047 Chronic Obstructive Pulmonary Disease
# 1032048 Overarching Conditions
# 1032049 Arthritis
#         Question
# 1       Hospitalizations for asthma
# 2       Hospitalizations for asthma
# 3       Hospitalizations for asthma
# 4       Hospitalizations for asthma
# 5       Hospitalizations for asthma
# 6       Hospitalizations for asthma
# 7       Hospitalizations for asthma
# 8       Hospitalizations for asthma
# 9       Hospitalizations for asthma
# 10      Hospitalizations for asthma
# 11      Hospitalizations for asthma
# 12      Asthma mortality rate
# 13      Asthma mortality rate
# 14      Asthma mortality rate
# 15      Asthma mortality rate
# 16      Asthma mortality rate
# 17      Asthma mortality rate
# 18      Asthma mortality rate
# 19      Asthma mortality rate
# 20      Asthma mortality rate
# 21      Asthma mortality rate
# 22      Asthma mortality rate
# 23      Asthma mortality rate
# 24      Asthma mortality rate
# 25      Asthma mortality rate
# 26      Asthma mortality rate
# 27      Asthma mortality rate
# 28      Asthma mortality rate
# 29      Asthma mortality rate
# 30      Cancer of the oral cavity and pharynx, mortality
# ⋮       ⋮
# 1032020 Binge drinking prevalence among women aged 18-44 years
# 1032021 Healthy weight among adults aged >= 18 years
# 1032022 Influenza vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease or stroke
# 1032023 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 1032024 Timeliness of routine health care checkup among women aged 18-44 years
# 1032025 Prevalence of chronic kidney disease among adults aged >= 18 years
# 1032026 No leisure-time physical activity among adults aged >= 18 years
# 1032027 Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes
# 1032028 Current asthma prevalence among adults aged >= 18 years
# 1032029 Current lack of health insurance among adults aged 18-64 years
# 1032030 Meeting aerobic physical activity guidelines for substantial health benefits and for muscle-strengthening activity among adults aged >= 18 years
# 1032031 Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease
# 1032032 Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes
# 1032033 Prevalence of current smoking among adults >= 18 with diagnosed chronic obstructive pulmonary disease
# 1032034 Six or more teeth lost among adults aged >= 65 years
# 1032035 Current smokeless tobacco use among adults aged >= 18 years
# 1032036 Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes
# 1032037 Influenza vaccination among noninstitutionalized adults aged >= 65 years with asthma
# 1032038 At least 14 recent mentally unhealthy days among women aged 18-44 years
# 1032039 Arthritis among adults aged >= 18 years who have heart disease
# 1032040 Recent activity limitation among adults aged >= 18 years
# 1032041 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 1032042 Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease
# 1032043 Prevalence of activity limitation among adults >= 45 years with diagnosed chronic obstructive pulmonary disease
# 1032044 Self-rated health status among women aged 18-44 years
# 1032045 Overweight or obesity among women aged 18-44 years
# 1032046 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 1032047 Prevalence of current smoking among adults >= 18 with diagnosed chronic obstructive pulmonary disease
# 1032048 Recent physically unhealthy days among adults aged >= 18 years
# 1032049 Arthritis among adults aged >= 18 years who have diabetes
#         Response DataValueUnit DataValueType           ⋯ LocationID TopicID
# 1       NA                     Number                  ⋯  5         AST
# 2       NA                     Number                  ⋯  8         AST
# 3       NA                     Number                  ⋯ 11         AST
# 4       NA                     Number                  ⋯ 13         AST
# 5       NA                     Number                  ⋯ 26         AST
# 6       NA                     Number                  ⋯ 30         AST
# 7       NA                     Number                  ⋯ 41         AST
# 8       NA                     Number                  ⋯ 72         AST
# 9       NA                     Number                  ⋯ 72         AST
# 10      NA                     Number                  ⋯ 55         AST
# 11      NA                     Number                  ⋯ 55         AST
# 12      NA                     Number                  ⋯  1         AST
# 13      NA                     Number                  ⋯ 16         AST
# 14      NA                     Number                  ⋯ 16         AST
# 15      NA       Number        Number                  ⋯ 17         AST
# 16      NA                     Number                  ⋯ 20         AST
# 17      NA                     Number                  ⋯ 20         AST
# 18      NA       Number        Number                  ⋯ 20         AST
# 19      NA                     Number                  ⋯ 22         AST
# 20      NA                     Number                  ⋯ 25         AST
# 21      NA                     Number                  ⋯ 24         AST
# 22      NA                     Number                  ⋯ 24         AST
# 23      NA                     Number                  ⋯ 27         AST
# 24      NA       Number        Number                  ⋯ 28         AST
# 25      NA                     Number                  ⋯ 37         AST
# 26      NA       Number        Number                  ⋯ 35         AST
# 27      NA                     Number                  ⋯ 48         AST
# 28      NA                     Number                  ⋯ 48         AST
# 29      NA                     Number                  ⋯ 48         AST
# 30      NA                     Average Annual Number   ⋯ 36         CAN
# ⋮       ⋮        ⋮             ⋮                       ⋱ ⋮          ⋮
# 1032020 NA       %             Crude Prevalence        ⋯ 44         ALC
# 1032021 NA       %             Crude Prevalence        ⋯ 44         NPAW
# 1032022 NA       %             Crude Prevalence        ⋯ 44         CVD
# 1032023 NA       %             Crude Prevalence        ⋯ 44         DIA
# 1032024 NA       %             Crude Prevalence        ⋯ 44         RPH
# 1032025 NA       %             Crude Prevalence        ⋯ 45         CKD
# 1032026 NA       %             Crude Prevalence        ⋯ 44         NPAW
# 1032027 NA       %             Crude Prevalence        ⋯ 44         DIA
# 1032028 NA       %             Age-adjusted Prevalence ⋯ 44         AST
# 1032029 NA       %             Age-adjusted Prevalence ⋯ 44         OVC
# 1032030 NA       %             Age-adjusted Prevalence ⋯ 44         NPAW
# 1032031 NA       %             Age-adjusted Prevalence ⋯ 44         CVD
# 1032032 NA       %             Crude Prevalence        ⋯ 44         DIA
# 1032033 NA       %             Age-adjusted Prevalence ⋯ 44         COPD
# 1032034 NA       %             Crude Prevalence        ⋯ 44         ORH
# 1032035 NA       %             Age-adjusted Prevalence ⋯ 44         TOB
# 1032036 NA       %             Crude Prevalence        ⋯ 44         DIA
# 1032037 NA       %             Crude Prevalence        ⋯ 44         AST
# 1032038 NA       %             Crude Prevalence        ⋯ 44         MTH
# 1032039 NA       %             Age-adjusted Prevalence ⋯ 44         ART
# 1032040 NA       Number        Mean                    ⋯ 44         OVC
# 1032041 NA       %             Crude Prevalence        ⋯ 44         DIA
# 1032042 NA       %             Crude Prevalence        ⋯ 44         CVD
# 1032043 NA       %             Age-adjusted Prevalence ⋯ 44         COPD
# 1032044 NA       %             Crude Prevalence        ⋯ 44         OVC
# 1032045 NA       %             Crude Prevalence        ⋯ 44         NPAW
# 1032046 NA       %             Age-adjusted Prevalence ⋯ 44         DIA
# 1032047 NA       %             Crude Prevalence        ⋯ 44         COPD
# 1032048 NA       Number        Mean                    ⋯ 44         OVC
# 1032049 NA       %             Age-adjusted Prevalence ⋯ NA
#         QuestionID DataValueTypeID StratificationCategoryID1 StratificationID1
# 1       AST3_1     NMBR            GENDER                    GENM
# 2       AST3_1     NMBR            OVERALL                   OVR
# 3       AST3_1     NMBR            OVERALL                   OVR
# 4       AST3_1     NMBR            GENDER                    GENF
# 5       AST3_1     NMBR            RACE                      HIS
# 6       AST3_1     NMBR            RACE                      HIS
# 7       AST3_1     NMBR            GENDER                    GENM
# 8       AST3_1     NMBR            OVERALL                   OVR
# 9       AST3_1     NMBR            OVERALL                   OVR
# 10      AST3_1     NMBR            GENDER                    GENM
# 11      AST3_1     NMBR            RACE                      HIS
# 12      AST4_1     NMBR            GENDER                    GENM
# 13      AST4_1     NMBR            OVERALL                   OVR
# 14      AST4_1     NMBR            OVERALL                   OVR
# 15      AST4_1     NMBR            GENDER                    GENM
# 16      AST4_1     NMBR            RACE                      WHT
# 17      AST4_1     NMBR            OVERALL                   OVR
# 18      AST4_1     NMBR            OVERALL                   OVR
# 19      AST4_1     NMBR            GENDER                    GENM
# 20      AST4_1     NMBR            GENDER                    GENM
# 21      AST4_1     NMBR            OVERALL                   OVR
# 22      AST4_1     NMBR            GENDER                    GENF
# 23      AST4_1     NMBR            OVERALL                   OVR
# 24      AST4_1     NMBR            OVERALL                   OVR
# 25      AST4_1     NMBR            GENDER                    GENM
# 26      AST4_1     NMBR            GENDER                    GENF
# 27      AST4_1     NMBR            GENDER                    GENF
# 28      AST4_1     NMBR            RACE                      HIS
# 29      AST4_1     NMBR            GENDER                    GENM
# 30      CAN10_2    AVGANNNMBR      GENDER                    GENM
# ⋮       ⋮          ⋮               ⋮                         ⋮
# 1032020 ALC2_3     CRDPREV         RACE                      HIS
# 1032021 NPAW3_1    CRDPREV         GENDER                    GENM
# 1032022 CVD9_2     CRDPREV         RACE                      MRC
# 1032023 DIA13_2    CRDPREV         GENDER                    GENF
# 1032024 RPH1_0     CRDPREV         RACE                      HIS
# 1032025 CKD3_0     CRDPREV         RACE                      MRC
# 1032026 NPAW10_0   CRDPREV         RACE                      MRC
# 1032027 DIA8_0     CRDPREV         RACE                      BLK
# 1032028 AST1_1     AGEADJPREV      GENDER                    GENM
# 1032029 OVC1_1     AGEADJPREV      RACE                      HIS
# 1032030 NPAW11_2   AGEADJPREV      RACE                      BLK
# 1032031 CVD10_1    AGEADJPREV      OVERALL                   OVR
# 1032032 DIA8_0     CRDPREV         RACE                      HIS
# 1032033 COPD3_0    AGEADJPREV      RACE                      MRC
# 1032034 ORH4_2     CRDPREV         RACE                      OTH
# 1032035 TOB2_2     AGEADJPREV      GENDER                    GENF
# 1032036 DIA8_0     CRDPREV         RACE                      HIS
# 1032037 AST5_2     CRDPREV         GENDER                    GENF
# 1032038 MTH2_0     CRDPREV         RACE                      HIS
# 1032039 ART1_4     AGEADJPREV      GENDER                    GENM
# 1032040 OVC7_2     MEAN            OVERALL                   OVR
# 1032041 DIA13_2    CRDPREV         RACE                      MRC
# 1032042 CVD10_1    CRDPREV         OVERALL                   OVR
# 1032043 COPD4_0_1  AGEADJPREV      RACE                      MRC
# 1032044 OVC6_2     CRDPREV         RACE                      BLK
# 1032045 NPAW2_3    CRDPREV         RACE                      BLK
# 1032046 DIA13_2    AGEADJPREV      RACE                      OTH
# 1032047 COPD3_0    CRDPREV         RACE                      HIS
# 1032048 OVC7_1     MEAN            RACE                      MRC
# 1032049
#         StratificationCategoryID2 StratificationID2 StratificationCategoryID3
# 1       NA                        NA                NA
# 2       NA                        NA                NA
# 3       NA                        NA                NA
# 4       NA                        NA                NA
# 5       NA                        NA                NA
# 6       NA                        NA                NA
# 7       NA                        NA                NA
# 8       NA                        NA                NA
# 9       NA                        NA                NA
# 10      NA                        NA                NA
# 11      NA                        NA                NA
# 12      NA                        NA                NA
# 13      NA                        NA                NA
# 14      NA                        NA                NA
# 15      NA                        NA                NA
# 16      NA                        NA                NA
# 17      NA                        NA                NA
# 18      NA                        NA                NA
# 19      NA                        NA                NA
# 20      NA                        NA                NA
# 21      NA                        NA                NA
# 22      NA                        NA                NA
# 23      NA                        NA                NA
# 24      NA                        NA                NA
# 25      NA                        NA                NA
# 26      NA                        NA                NA
# 27      NA                        NA                NA
# 28      NA                        NA                NA
# 29      NA                        NA                NA
# 30      NA                        NA                NA
# ⋮       ⋮                         ⋮                 ⋮
# 1032020 NA                        NA                NA
# 1032021 NA                        NA                NA
# 1032022 NA                        NA                NA
# 1032023 NA                        NA                NA
# 1032024 NA                        NA                NA
# 1032025 NA                        NA                NA
# 1032026 NA                        NA                NA
# 1032027 NA                        NA                NA
# 1032028 NA                        NA                NA
# 1032029 NA                        NA                NA
# 1032030 NA                        NA                NA
# 1032031 NA                        NA                NA
# 1032032 NA                        NA                NA
# 1032033 NA                        NA                NA
# 1032034 NA                        NA                NA
# 1032035 NA                        NA                NA
# 1032036 NA                        NA                NA
# 1032037 NA                        NA                NA
# 1032038 NA                        NA                NA
# 1032039 NA                        NA                NA
# 1032040 NA                        NA                NA
# 1032041 NA                        NA                NA
# 1032042 NA                        NA                NA
# 1032043 NA                        NA                NA
# 1032044 NA                        NA                NA
# 1032045 NA                        NA                NA
# 1032046 NA                        NA                NA
# 1032047 NA                        NA                NA
# 1032048 NA                        NA                NA
# 1032049 NA                        NA                NA
#         StratificationID3
# 1       NA
# 2       NA
# 3       NA
# 4       NA
# 5       NA
# 6       NA
# 7       NA
# 8       NA
# 9       NA
# 10      NA
# 11      NA
# 12      NA
# 13      NA
# 14      NA
# 15      NA
# 16      NA
# 17      NA
# 18      NA
# 19      NA
# 20      NA
# 21      NA
# 22      NA
# 23      NA
# 24      NA
# 25      NA
# 26      NA
# 27      NA
# 28      NA
# 29      NA
# 30      NA
# ⋮       ⋮
# 1032020 NA
# 1032021 NA
# 1032022 NA
# 1032023 NA
# 1032024 NA
# 1032025 NA
# 1032026 NA
# 1032027 NA
# 1032028 NA
# 1032029 NA
# 1032030 NA
# 1032031 NA
# 1032032 NA
# 1032033 NA
# 1032034 NA
# 1032035 NA
# 1032036 NA
# 1032037 NA
# 1032038 NA
# 1032039 NA
# 1032040 NA
# 1032041 NA
# 1032042 NA
# 1032043 NA
# 1032044 NA
# 1032045 NA
# 1032046 NA
# 1032047 NA
# 1032048 NA
# 1032049 NA

# %% [markdown]
# 3. zobrazenie sumarizácie pre všetky premenné
#
#    - obsahuje základné matematické štatistiky pre numerické premenné
#    - obsahuje typ kategorickej premennej
#
#    + **jednoduché zistenie zbytočných premenných**

# %%
summary(data)
# Out:
#    YearStart       YearEnd     LocationAbbr       LocationDesc
#  Min.   :2001   Min.   :2001   Length:1032049     Length:1032049
#  1st Qu.:2012   1st Qu.:2013   Class :character   Class :character
#  Median :2015   Median :2016   Mode  :character   Mode  :character
#  Mean   :2015   Mean   :2016
#  3rd Qu.:2018   3rd Qu.:2018
#  Max.   :2021   Max.   :2021
#
#   DataSource           Topic             Question         Response
#  Length:1032049     Length:1032049     Length:1032049     Mode:logical
#  Class :character   Class :character   Class :character   NA's:1032049
#  Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  DataValueUnit      DataValueType       DataValue          DataValueAlt
#  Length:1032049     Length:1032049     Length:1032049     Min.   :      0.0
#  Class :character   Class :character   Class :character   1st Qu.:     16.2
#  Mode  :character   Mode  :character   Mode  :character   Median :     41.0
#                                                           Mean   :   1134.1
#                                                           3rd Qu.:     81.3
#                                                           Max.   :2925456.0
#                                                           NA's   :321968
#  DataValueFootnoteSymbol DatavalueFootnote  LowConfidenceLimit
#  Length:1032049          Length:1032049     Min.   :   0.0
#  Class :character        Class :character   1st Qu.:  10.8
#  Mode  :character        Mode  :character   Median :  28.5
#                                             Mean   :  53.2
#                                             3rd Qu.:  57.9
#                                             Max.   :2541.6
#                                             NA's   :444089
#  HighConfidenceLimit StratificationCategory1 Stratification1
#  Min.   :   0.0      Length:1032049          Length:1032049
#  1st Qu.:  15.9      Class :character        Class :character
#  Median :  40.7      Mode  :character        Mode  :character
#  Mean   :  64.9
#  3rd Qu.:  72.4
#  Max.   :3530.5
#  NA's   :444090
#  StratificationCategory2 Stratification2 StratificationCategory3
#  Mode:logical            Mode:logical    Mode:logical
#  NA's:1032049            NA's:1032049    NA's:1032049
#
#
#
#
#
#  Stratification3 GeoLocation        ResponseID       LocationID
#  Mode:logical    Length:1032049     Mode:logical   Min.   : 1.00
#  NA's:1032049    Class :character   NA's:1032049   1st Qu.:15.00
#                  Mode  :character                  Median :27.00
#                                                    Mean   :27.57
#                                                    3rd Qu.:38.00
#                                                    Max.   :78.00
#                                                    NA's   :1
#    TopicID           QuestionID        DataValueTypeID
#  Length:1032049     Length:1032049     Length:1032049
#  Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  StratificationCategoryID1 StratificationID1  StratificationCategoryID2
#  Length:1032049            Length:1032049     Mode:logical
#  Class :character          Class :character   NA's:1032049
#  Mode  :character          Mode  :character
#
#
#
#
#  StratificationID2 StratificationCategoryID3 StratificationID3
#  Mode:logical      Mode:logical              Mode:logical
#  NA's:1032049      NA's:1032049              NA's:1032049

# %% [markdown]
# 4. Zobrazenie prvých a posledných riadkov datasetu
#
#    - overenie, či bol dataset načítaný správne

# %%
head(data)
tail(data)

# %% [markdown]
# 5. Zobrazenie názvov premenných
#
#     - užitočné, pri vytváraní tabuliek, grafov, ..

# %%
colnames(data)

# %% [markdown]
# ##### A. Kategorické premenné

# %% [markdown]
# 6. Overenie hodnôt v premenných

# %%
# there are only NA's
unique(data$Response)
unique(data$StratificationID2)
# Out:
# [1] NA
# [1] NA

# %%
# there are more values
unique(data$Topic)
# Out:
#  [1] "Asthma"
#  [2] "Cancer"
#  [3] "Chronic Kidney Disease"
#  [4] "Chronic Obstructive Pulmonary Disease"
#  [5] "Cardiovascular Disease"
#  [6] "Diabetes"
#  [7] "Disability"
#  [8] "Reproductive Health"
#  [9] "Tobacco"
# [10] "Alcohol"
# [11] "Arthritis"
# [12] "Nutrition, Physical Activity, and Weight Status"
# [13] "Mental Health"
# [14] "Older Adults"
# [15] "Oral Health"
# [16] "Overarching Conditions"
# [17] "Immunization"

# %% [markdown]
# 7. Vytvorenie tabuľky
#
#    - počet záznamov v datasete pre danú hodnotu premennej
#    - tabuľku môžete tiež vytvárať pre viac premenných (premenné sú oddelené čiarkou), výsledkom je tabuľka, ktorá obsahuje počet záznamov vyskytujúcich sa v datasete pre jednotlivé kombinácie hodnôt vybraných premenných

# %%
table(data$LocationDesc)

table(data$LocationDesc, data$YearStart)

# %% [markdown]
# 8. Triedenie tabuľky
#
#     - predvolene triedená podľa hodnôt premennej podľa abecedy
#     - utrieďte tabuľku tak, aby na začiatku tabuľky boli štáty ktoré majú v datasete najviac záznamov
#     - funkcia sort() - www.rdocumentation.org/packages/base/versions/3.6.2/topics/sort

# %%
# TODO - sort the table

new_table <- sort(table(data$LocationDesc), decreasing = TRUE)

new_table

# %% [markdown]
# 9. Grafické zobrazenie počtu hodnôt
#
#     - vytvorte čiarový graf, ktorý vám zobrazí počet záznamov pre jednotlivé kategórie (premenná Topics) v datasete
#     - funkcia barplot() - www.rdocumentation.org/packages/graphics/versions/3.6.2/topics/barplot
#     - ďalšie formátovanie - www.r-graph-gallery.com/210-custom-barplot-layout.html

# %%
# settings for plot visualisation
options(repr.plot.height = 5, repr.plot.res = 200)

# TODO - create barplot from the previously sorted table (default = vertical)
new_table <- sort(table(data$Topic), decreasing = TRUE)

# barplot(new_table)

# set margin
par(mar=c(12, 5, 4, 2) + 0.1) # horizontal

# TODO - set the labels' orientation to perpendicular (find 'las' attribute in the advanced formatting link)
barplot(new_table, las=2)

# set margin
par(mar=c(5, 12, 4, 2) + 0.1) # horizontal

# TODO - change the barplot to horizontal (find 'horiz' attribute in the advanced formatting link)
barplot(new_table, las=2, horiz=TRUE)

# %% [markdown]
#
# ##### B. Numerické premenné

# %% [markdown]
# 10. Zobrazenie matematických vlastností
#
#     - variancia (variance): priemerná kvadratická odchýlka od priemeru
#     - smerodajná odchýlka (standard deviation): druhá odmocnina variancie
#     - horný/dolný kvartil (quartile): hodnota, od ktorej je 25%, resp. 75% hodnôt menších
#     - medián (median) - rozdeľuje súbor údajov na dve rovnaké polovice (polovica údajov je pred ním, polovica za ním)
#     - priemer (mean) - súčet všetkých hodnôt delený počtom hodnôt, ovplyvnený extrémnymi hodnotami
#     - NA - prázdne hodnoty
#
# Možnosť použiť ďalšie funkcie ako sd(), var(), boxplot.stats() a pod.

# %%
# summary shows min, max, 1.st and 3.rd Quartile, Median, Mean and NA's
summary(data$DataValueAlt)

# %% [markdown]
# 11. Zobrazenie chýbajúcich hodnôt v datasete
#     - chýbajúce hodnoty - NA - www.rdocumentation.org/packages/base/versions/3.6.2/topics/NA

# %%
# see data in variable
data$LowConfidenceLimit

# is.na - function that returns logical value, whether the value is NA or not
is.na(data$LowConfidenceLimit)

# %%
# display all the variables of all the data, where LowConfidenceLimit is NA
data[is.na(data$LowConfidenceLimit),]

# %% [markdown]
# ## Očistenie (clean)
#
# Očistenie údajov zahŕňa:
# - overenie/úpravu typov premenných
# - výber podstatných premenných
# - filtrovanie hodnôt, podľa toho čo chceme ďalej spracovávať
# - odstránenie NA a duplicitných údajov

# %% [markdown]
# 1. Overenie a zmena typu premennej
#     - pri kategorických premenných je dobré zmeniť typ premennej z 'character' na 'factor', pretože pri niektorých štatistických testoch (napr. ANOVA) sa môže stať, že  táto premenná nebude vyhodnocovaná ako kateogrická, čo ovplyvní typ a výsledok použitého testu
#
#     - as.factor - www.rdocumentation.org/packages/h2o/versions/3.42.0.2/topics/as.factor

# %%
# class function shows the variable type
class(data$Topic)

# %%
# change categorical variable types to factor
data$LocationAbbr <- as.factor(data$LocationAbbr)
data$LocationDesc <- as.factor(data$LocationDesc)
data$DataSource <- as.factor(data$DataSource)
data$Topic <- as.factor(data$Topic)
data$TopicID <- as.factor(data$TopicID)
data$Question <- as.factor(data$Question)
data$QuestionID <- as.factor(data$QuestionID)
data$StratificationCategory1 <- as.factor(data$StratificationCategory1)
data$DataValueType <- as.factor(data$DataValueType)

# %% [markdown]
# 2. Overenie hodnôt premennej (špecifické pre premenné typu factor)
#
#    - rozdiel unique/factor - unique vracia unikátne hodnoty prítomné vo vzorke, factor vracia všetky hodnoty, ktoré má premenná definované a môže ich nadobúdať (niečo ako výber hodnoty z dropdownu)

# %%
levels(data$StratificationCategory1)

# %% [markdown]
# 3. Výber podstatných premenných
#
#    - redukcia datasetu - len premenné ktoré nás zaujímajú/majú pre nás nejakú hodnotu
#    - funkcia select - https://dplyr.tidyverse.org/reference/select.html
#    - pre opakujúce sa názvy použite funkciu starts_with - https://www.rdocumentation.org/packages/tidyselect/versions/1.2.0/topics/starts_with

# %% [raw]
# Zoznam premenných v datasete:
#
# YearStart, YearEnd, LocationAbbr, LocationDesc, DataSource, Topic, Question, Response, DataValueUnit, DataValueType, DataValue, DataValueAlt, DataValueFootnoteSymbol, DatavalueFootnote, LowConfidenceLimit, HighConfidenceLimit, StratificationCategory1, Stratification1, StratificationCategory2, Stratification2, StratificationCategory3, Stratification3, GeoLocation, ResponseID, LocationID, TopicID, QuestionID, DataValueTypeID, StratificationCategoryID1, StratificationID1, StratificationCategoryID2, StratificationID2, StratificationCategoryID3, StratificationID3

# %% [markdown]
# **Ktoré premenné na základe doterajších znalostí môžeme vynechať?**

# %%
# %>% in R means redirecting the output to some function, similar to >> in bash

data %>% 
    select(YearStart, YearEnd, starts_with("Location"), DataSource, TopicID, Topic, QuestionID, Question, starts_with("DataValue"), LowConfidenceLimit,
           HighConfidenceLimit, StratificationCategoryID1, StratificationID1, StratificationCategory1, Stratification1,
           -DatavalueFootnote, -DataValueFootnoteSymbol)
# Out:
#         YearStart YearEnd LocationAbbr LocationDesc         LocationID
# 1       2014      2014    AR           Arkansas              5
# 2       2018      2018    CO           Colorado              8
# 3       2018      2018    DC           District of Columbia 11
# 4       2017      2017    GA           Georgia              13
# 5       2010      2010    MI           Michigan             26
# 6       2015      2015    MT           Montana              30
# 7       2013      2013    OR           Oregon               41
# 8       2013      2013    PR           Puerto Rico          72
# 9       2017      2017    PR           Puerto Rico          72
# 10      2010      2010    WI           Wisconsin            55
# 11      2016      2016    WI           Wisconsin            55
# 12      2014      2014    AL           Alabama               1
# 13      2015      2015    ID           Idaho                16
# 14      2016      2016    ID           Idaho                16
# 15      2020      2020    IL           Illinois             17
# 16      2012      2012    KS           Kansas               20
# 17      2015      2015    KS           Kansas               20
# 18      2018      2018    KS           Kansas               20
# 19      2017      2017    LA           Louisiana            22
# 20      2017      2017    MA           Massachusetts        25
# 21      2010      2010    MD           Maryland             24
# 22      2014      2014    MD           Maryland             24
# 23      2010      2010    MN           Minnesota            27
# 24      2019      2019    MS           Mississippi          28
# 25      2014      2014    NC           North Carolina       37
# 26      2020      2020    NM           New Mexico           35
# 27      2010      2010    TX           Texas                48
# 28      2011      2011    TX           Texas                48
# 29      2016      2016    TX           Texas                48
# 30      2008      2012    NY           New York             36
# ⋮       ⋮         ⋮       ⋮            ⋮                    ⋮
# 1032020 2012      2012    RI           Rhode Island         44
# 1032021 2014      2014    RI           Rhode Island         44
# 1032022 2021      2021    RI           Rhode Island         44
# 1032023 2014      2014    RI           Rhode Island         44
# 1032024 2011      2011    RI           Rhode Island         44
# 1032025 2021      2021    SC           South Carolina       45
# 1032026 2014      2014    RI           Rhode Island         44
# 1032027 2020      2020    RI           Rhode Island         44
# 1032028 2016      2016    RI           Rhode Island         44
# 1032029 2012      2012    RI           Rhode Island         44
# 1032030 2013      2013    RI           Rhode Island         44
# 1032031 2018      2018    RI           Rhode Island         44
# 1032032 2016      2016    RI           Rhode Island         44
# 1032033 2019      2019    RI           Rhode Island         44
# 1032034 2020      2020    RI           Rhode Island         44
# 1032035 2015      2015    RI           Rhode Island         44
# 1032036 2020      2020    RI           Rhode Island         44
# 1032037 2013      2013    RI           Rhode Island         44
# 1032038 2020      2020    RI           Rhode Island         44
# 1032039 2016      2016    RI           Rhode Island         44
# 1032040 2017      2017    RI           Rhode Island         44
# 1032041 2016      2016    RI           Rhode Island         44
# 1032042 2021      2021    RI           Rhode Island         44
# 1032043 2012      2012    RI           Rhode Island         44
# 1032044 2019      2019    RI           Rhode Island         44
# 1032045 2012      2012    RI           Rhode Island         44
# 1032046 2019      2019    RI           Rhode Island         44
# 1032047 2016      2016    RI           Rhode Island         44
# 1032048 2015      2015    RI           Rhode Island         44
# 1032049 2014      2014    RI           Rhode Island         NA
#         DataSource        TopicID
# 1       SEDD; SID         AST
# 2       SEDD; SID         AST
# 3       SEDD; SID         AST
# 4       SEDD; SID         AST
# 5       SEDD; SID         AST
# 6       SEDD; SID         AST
# 7       SEDD; SID         AST
# 8       SEDD; SID         AST
# 9       SEDD; SID         AST
# 10      SEDD; SID         AST
# 11      SEDD; SID         AST
# 12      NVSS              AST
# 13      NVSS              AST
# 14      NVSS              AST
# 15      NVSS              AST
# 16      NVSS              AST
# 17      NVSS              AST
# 18      NVSS              AST
# 19      NVSS              AST
# 20      NVSS              AST
# 21      NVSS              AST
# 22      NVSS              AST
# 23      NVSS              AST
# 24      NVSS              AST
# 25      NVSS              AST
# 26      NVSS              AST
# 27      NVSS              AST
# 28      NVSS              AST
# 29      NVSS              AST
# 30      Death Certificate CAN
# ⋮       ⋮                 ⋮
# 1032020 BRFSS             ALC
# 1032021 BRFSS             NPAW
# 1032022 BRFSS             CVD
# 1032023 BRFSS             DIA
# 1032024 BRFSS             RPH
# 1032025 BRFSS             CKD
# 1032026 BRFSS             NPAW
# 1032027 BRFSS             DIA
# 1032028 BRFSS             AST
# 1032029 BRFSS             OVC
# 1032030 BRFSS             NPAW
# 1032031 BRFSS             CVD
# 1032032 BRFSS             DIA
# 1032033 BRFSS             COPD
# 1032034 BRFSS             ORH
# 1032035 BRFSS             TOB
# 1032036 BRFSS             DIA
# 1032037 BRFSS             AST
# 1032038 BRFSS             MTH
# 1032039 BRFSS             ART
# 1032040 BRFSS             OVC
# 1032041 BRFSS             DIA
# 1032042 BRFSS             CVD
# 1032043 BRFSS             COPD
# 1032044 BRFSS             OVC
# 1032045 BRFSS             NPAW
# 1032046 BRFSS             DIA
# 1032047 BRFSS             COPD
# 1032048 BRFSS             OVC
# 1032049 BRFSS
#         Topic                                           QuestionID
# 1       Asthma                                          AST3_1
# 2       Asthma                                          AST3_1
# 3       Asthma                                          AST3_1
# 4       Asthma                                          AST3_1
# 5       Asthma                                          AST3_1
# 6       Asthma                                          AST3_1
# 7       Asthma                                          AST3_1
# 8       Asthma                                          AST3_1
# 9       Asthma                                          AST3_1
# 10      Asthma                                          AST3_1
# 11      Asthma                                          AST3_1
# 12      Asthma                                          AST4_1
# 13      Asthma                                          AST4_1
# 14      Asthma                                          AST4_1
# 15      Asthma                                          AST4_1
# 16      Asthma                                          AST4_1
# 17      Asthma                                          AST4_1
# 18      Asthma                                          AST4_1
# 19      Asthma                                          AST4_1
# 20      Asthma                                          AST4_1
# 21      Asthma                                          AST4_1
# 22      Asthma                                          AST4_1
# 23      Asthma                                          AST4_1
# 24      Asthma                                          AST4_1
# 25      Asthma                                          AST4_1
# 26      Asthma                                          AST4_1
# 27      Asthma                                          AST4_1
# 28      Asthma                                          AST4_1
# 29      Asthma                                          AST4_1
# 30      Cancer                                          CAN10_2
# ⋮       ⋮                                               ⋮
# 1032020 Alcohol                                         ALC2_3
# 1032021 Nutrition, Physical Activity, and Weight Status NPAW3_1
# 1032022 Cardiovascular Disease                          CVD9_2
# 1032023 Diabetes                                        DIA13_2
# 1032024 Reproductive Health                             RPH1_0
# 1032025 Chronic Kidney Disease                          CKD3_0
# 1032026 Nutrition, Physical Activity, and Weight Status NPAW10_0
# 1032027 Diabetes                                        DIA8_0
# 1032028 Asthma                                          AST1_1
# 1032029 Overarching Conditions                          OVC1_1
# 1032030 Nutrition, Physical Activity, and Weight Status NPAW11_2
# 1032031 Cardiovascular Disease                          CVD10_1
# 1032032 Diabetes                                        DIA8_0
# 1032033 Chronic Obstructive Pulmonary Disease           COPD3_0
# 1032034 Oral Health                                     ORH4_2
# 1032035 Tobacco                                         TOB2_2
# 1032036 Diabetes                                        DIA8_0
# 1032037 Asthma                                          AST5_2
# 1032038 Mental Health                                   MTH2_0
# 1032039 Arthritis                                       ART1_4
# 1032040 Overarching Conditions                          OVC7_2
# 1032041 Diabetes                                        DIA13_2
# 1032042 Cardiovascular Disease                          CVD10_1
# 1032043 Chronic Obstructive Pulmonary Disease           COPD4_0_1
# 1032044 Overarching Conditions                          OVC6_2
# 1032045 Nutrition, Physical Activity, and Weight Status NPAW2_3
# 1032046 Diabetes                                        DIA13_2
# 1032047 Chronic Obstructive Pulmonary Disease           COPD3_0
# 1032048 Overarching Conditions                          OVC7_1
# 1032049 Arthritis
#         Question
# 1       Hospitalizations for asthma
# 2       Hospitalizations for asthma
# 3       Hospitalizations for asthma
# 4       Hospitalizations for asthma
# 5       Hospitalizations for asthma
# 6       Hospitalizations for asthma
# 7       Hospitalizations for asthma
# 8       Hospitalizations for asthma
# 9       Hospitalizations for asthma
# 10      Hospitalizations for asthma
# 11      Hospitalizations for asthma
# 12      Asthma mortality rate
# 13      Asthma mortality rate
# 14      Asthma mortality rate
# 15      Asthma mortality rate
# 16      Asthma mortality rate
# 17      Asthma mortality rate
# 18      Asthma mortality rate
# 19      Asthma mortality rate
# 20      Asthma mortality rate
# 21      Asthma mortality rate
# 22      Asthma mortality rate
# 23      Asthma mortality rate
# 24      Asthma mortality rate
# 25      Asthma mortality rate
# 26      Asthma mortality rate
# 27      Asthma mortality rate
# 28      Asthma mortality rate
# 29      Asthma mortality rate
# 30      Cancer of the oral cavity and pharynx, mortality
# ⋮       ⋮
# 1032020 Binge drinking prevalence among women aged 18-44 years
# 1032021 Healthy weight among adults aged >= 18 years
# 1032022 Influenza vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease or stroke
# 1032023 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 1032024 Timeliness of routine health care checkup among women aged 18-44 years
# 1032025 Prevalence of chronic kidney disease among adults aged >= 18 years
# 1032026 No leisure-time physical activity among adults aged >= 18 years
# 1032027 Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes
# 1032028 Current asthma prevalence among adults aged >= 18 years
# 1032029 Current lack of health insurance among adults aged 18-64 years
# 1032030 Meeting aerobic physical activity guidelines for substantial health benefits and for muscle-strengthening activity among adults aged >= 18 years
# 1032031 Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease
# 1032032 Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes
# 1032033 Prevalence of current smoking among adults >= 18 with diagnosed chronic obstructive pulmonary disease
# 1032034 Six or more teeth lost among adults aged >= 65 years
# 1032035 Current smokeless tobacco use among adults aged >= 18 years
# 1032036 Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes
# 1032037 Influenza vaccination among noninstitutionalized adults aged >= 65 years with asthma
# 1032038 At least 14 recent mentally unhealthy days among women aged 18-44 years
# 1032039 Arthritis among adults aged >= 18 years who have heart disease
# 1032040 Recent activity limitation among adults aged >= 18 years
# 1032041 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 1032042 Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease
# 1032043 Prevalence of activity limitation among adults >= 45 years with diagnosed chronic obstructive pulmonary disease
# 1032044 Self-rated health status among women aged 18-44 years
# 1032045 Overweight or obesity among women aged 18-44 years
# 1032046 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 1032047 Prevalence of current smoking among adults >= 18 with diagnosed chronic obstructive pulmonary disease
# 1032048 Recent physically unhealthy days among adults aged >= 18 years
# 1032049 Arthritis among adults aged >= 18 years who have diabetes
#         ⋯ DataValueType           DataValue DataValueAlt DataValueTypeID
# 1       ⋯ Number                  916        916         NMBR
# 2       ⋯ Number                  2227      2227         NMBR
# 3       ⋯ Number                  708        708         NMBR
# 4       ⋯ Number                  3520      3520         NMBR
# 5       ⋯ Number                  123        123         NMBR
# 6       ⋯ Number                              NA         NMBR
# 7       ⋯ Number                  760        760         NMBR
# 8       ⋯ Number                              NA         NMBR
# 9       ⋯ Number                              NA         NMBR
# 10      ⋯ Number                  1967      1967         NMBR
# 11      ⋯ Number                  110        110         NMBR
# 12      ⋯ Number                  22          22         NMBR
# 13      ⋯ Number                  21          21         NMBR
# 14      ⋯ Number                  21          21         NMBR
# 15      ⋯ Number                  89          89         NMBR
# 16      ⋯ Number                  24          24         NMBR
# 17      ⋯ Number                  29          29         NMBR
# 18      ⋯ Number                  29          29         NMBR
# 19      ⋯ Number                  21          21         NMBR
# 20      ⋯ Number                  28          28         NMBR
# 21      ⋯ Number                  71          71         NMBR
# 22      ⋯ Number                  58          58         NMBR
# 23      ⋯ Number                  73          73         NMBR
# 24      ⋯ Number                  58          58         NMBR
# 25      ⋯ Number                  39          39         NMBR
# 26      ⋯ Number                  26          26         NMBR
# 27      ⋯ Number                  111        111         NMBR
# 28      ⋯ Number                  24          24         NMBR
# 29      ⋯ Number                  66          66         NMBR
# 30      ⋯ Average Annual Number   329        329         AVGANNNMBR
# ⋮       ⋱ ⋮                       ⋮         ⋮            ⋮
# 1032020 ⋯ Crude Prevalence        11.3      11.3         CRDPREV
# 1032021 ⋯ Crude Prevalence        28.9      28.9         CRDPREV
# 1032022 ⋯ Crude Prevalence                    NA         CRDPREV
# 1032023 ⋯ Crude Prevalence        83.1      83.1         CRDPREV
# 1032024 ⋯ Crude Prevalence        65.9      65.9         CRDPREV
# 1032025 ⋯ Crude Prevalence                    NA         CRDPREV
# 1032026 ⋯ Crude Prevalence                    NA         CRDPREV
# 1032027 ⋯ Crude Prevalence                    NA         CRDPREV
# 1032028 ⋯ Age-adjusted Prevalence 7.0        7.0         AGEADJPREV
# 1032029 ⋯ Age-adjusted Prevalence 42.3      42.3         AGEADJPREV
# 1032030 ⋯ Age-adjusted Prevalence 20.6      20.6         AGEADJPREV
# 1032031 ⋯ Age-adjusted Prevalence 31.4      31.4         AGEADJPREV
# 1032032 ⋯ Crude Prevalence        58.3      58.3         CRDPREV
# 1032033 ⋯ Age-adjusted Prevalence             NA         AGEADJPREV
# 1032034 ⋯ Crude Prevalence                    NA         CRDPREV
# 1032035 ⋯ Age-adjusted Prevalence 0.4        0.4         AGEADJPREV
# 1032036 ⋯ Crude Prevalence        65.6      65.6         CRDPREV
# 1032037 ⋯ Crude Prevalence        73.3      73.3         CRDPREV
# 1032038 ⋯ Crude Prevalence        11.5      11.5         CRDPREV
# 1032039 ⋯ Age-adjusted Prevalence 44.5      44.5         AGEADJPREV
# 1032040 ⋯ Mean                    3.0        3.0         MEAN
# 1032041 ⋯ Crude Prevalence                    NA         CRDPREV
# 1032042 ⋯ Crude Prevalence        49.9      49.9         CRDPREV
# 1032043 ⋯ Age-adjusted Prevalence             NA         AGEADJPREV
# 1032044 ⋯ Crude Prevalence        95.9      95.9         CRDPREV
# 1032045 ⋯ Crude Prevalence                    NA         CRDPREV
# 1032046 ⋯ Age-adjusted Prevalence             NA         AGEADJPREV
# 1032047 ⋯ Crude Prevalence                    NA         CRDPREV
# 1032048 ⋯ Mean                    5.6        5.6         MEAN
# 1032049 ⋯ Age-adjusted Prevalence 37.4      37.4
#         LowConfidenceLimit HighConfidenceLimit StratificationCategoryID1
# 1       NA                 NA                  GENDER
# 2       NA                 NA                  OVERALL
# 3       NA                 NA                  OVERALL
# 4       NA                 NA                  GENDER
# 5       NA                 NA                  RACE
# 6       NA                 NA                  RACE
# 7       NA                 NA                  GENDER
# 8       NA                 NA                  OVERALL
# 9       NA                 NA                  OVERALL
# 10      NA                 NA                  GENDER
# 11      NA                 NA                  RACE
# 12      NA                 NA                  GENDER
# 13      NA                 NA                  OVERALL
# 14      NA                 NA                  OVERALL
# 15      NA                 NA                  GENDER
# 16      NA                 NA                  RACE
# 17      NA                 NA                  OVERALL
# 18      NA                 NA                  OVERALL
# 19      NA                 NA                  GENDER
# 20      NA                 NA                  GENDER
# 21      NA                 NA                  OVERALL
# 22      NA                 NA                  GENDER
# 23      NA                 NA                  OVERALL
# 24      NA                 NA                  OVERALL
# 25      NA                 NA                  GENDER
# 26      NA                 NA                  GENDER
# 27      NA                 NA                  GENDER
# 28      NA                 NA                  RACE
# 29      NA                 NA                  GENDER
# 30      NA                 NA                  GENDER
# ⋮       ⋮                  ⋮                   ⋮
# 1032020  6.2               19.7                RACE
# 1032021 26.3               31.7                GENDER
# 1032022   NA                 NA                RACE
# 1032023 76.5               88.1                GENDER
# 1032024 56.1               74.6                RACE
# 1032025   NA                 NA                RACE
# 1032026   NA                 NA                RACE
# 1032027   NA                 NA                RACE
# 1032028  5.8                8.5                GENDER
# 1032029 36.2               48.7                RACE
# 1032030 14.3               28.6                RACE
# 1032031 23.9               39.9                OVERALL
# 1032032 41.0               73.8                RACE
# 1032033   NA                 NA                RACE
# 1032034   NA                 NA                RACE
# 1032035  0.2                0.8                GENDER
# 1032036 50.8               77.8                RACE
# 1032037 63.3               81.4                GENDER
# 1032038  7.7               16.9                RACE
# 1032039 31.7               58.1                GENDER
# 1032040  2.7                3.2                OVERALL
# 1032041   NA                 NA                RACE
# 1032042 36.5               63.4                OVERALL
# 1032043   NA                 NA                RACE
# 1032044 90.1               98.4                RACE
# 1032045   NA                 NA                RACE
# 1032046   NA                 NA                RACE
# 1032047   NA                 NA                RACE
# 1032048  2.5                8.6                RACE
# 1032049 27.0                 NA
#         StratificationID1 StratificationCategory1 Stratification1
# 1       GENM              Gender                  Male
# 2       OVR               Overall                 Overall
# 3       OVR               Overall                 Overall
# 4       GENF              Gender                  Female
# 5       HIS               Race/Ethnicity          Hispanic
# 6       HIS               Race/Ethnicity          Hispanic
# 7       GENM              Gender                  Male
# 8       OVR               Overall                 Overall
# 9       OVR               Overall                 Overall
# 10      GENM              Gender                  Male
# 11      HIS               Race/Ethnicity          Hispanic
# 12      GENM              Gender                  Male
# 13      OVR               Overall                 Overall
# 14      OVR               Overall                 Overall
# 15      GENM              Gender                  Male
# 16      WHT               Race/Ethnicity          White, non-Hispanic
# 17      OVR               Overall                 Overall
# 18      OVR               Overall                 Overall
# 19      GENM              Gender                  Male
# 20      GENM              Gender                  Male
# 21      OVR               Overall                 Overall
# 22      GENF              Gender                  Female
# 23      OVR               Overall                 Overall
# 24      OVR               Overall                 Overall
# 25      GENM              Gender                  Male
# 26      GENF              Gender                  Female
# 27      GENF              Gender                  Female
# 28      HIS               Race/Ethnicity          Hispanic
# 29      GENM              Gender                  Male
# 30      GENM              Gender                  Male
# ⋮       ⋮                 ⋮                       ⋮
# 1032020 HIS               Race/Ethnicity          Hispanic
# 1032021 GENM              Gender                  Male
# 1032022 MRC               Race/Ethnicity          Multiracial, non-Hispanic
# 1032023 GENF              Gender                  Female
# 1032024 HIS               Race/Ethnicity          Hispanic
# 1032025 MRC               Race/Ethnicity          Multiracial, non-Hispanic
# 1032026 MRC               Race/Ethnicity          Multiracial, non-Hispanic
# 1032027 BLK               Race/Ethnicity          Black, non-Hispanic
# 1032028 GENM              Gender                  Male
# 1032029 HIS               Race/Ethnicity          Hispanic
# 1032030 BLK               Race/Ethnicity          Black, non-Hispanic
# 1032031 OVR               Overall                 Overall
# 1032032 HIS               Race/Ethnicity          Hispanic
# 1032033 MRC               Race/Ethnicity          Multiracial, non-Hispanic
# 1032034 OTH               Race/Ethnicity          Other, non-Hispanic
# 1032035 GENF              Gender                  Female
# 1032036 HIS               Race/Ethnicity          Hispanic
# 1032037 GENF              Gender                  Female
# 1032038 HIS               Race/Ethnicity          Hispanic
# 1032039 GENM              Gender                  Male
# 1032040 OVR               Overall                 Overall
# 1032041 MRC               Race/Ethnicity          Multiracial, non-Hispanic
# 1032042 OVR               Overall                 Overall
# 1032043 MRC               Race/Ethnicity          Multiracial, non-Hispanic
# 1032044 BLK               Race/Ethnicity          Black, non-Hispanic
# 1032045 BLK               Race/Ethnicity          Black, non-Hispanic
# 1032046 OTH               Race/Ethnicity          Other, non-Hispanic
# 1032047 HIS               Race/Ethnicity          Hispanic
# 1032048 MRC               Race/Ethnicity          Multiracial, non-Hispanic
# 1032049

# %% [markdown]
# V premennej DataValueUnit sa v niektorých záznamoch nachádzajú prázdne hodnoty.
#
# **Malo by význam ich vyfiltrovať a skontrolovať?**

# %%
Ak áno tak kedy ?

# %% [markdown]
# 4. Výber záznamov s ktorými chceme pracovať
#
#    - napríklad chceme pracovať len s otázkami ktoré sa týkajú cukrovky (TopicID = 'DIA') a boli zaznamenané od roku 2015.
#    - doplňte predošlý výber údajov o filtrovanie tak, že výstup z funkcie select presmerujete do ďalšej funkcie, kde vyfiltrujete údaje
#    - použite funkciu filter - https://dplyr.tidyverse.org/articles/grouping.html?q=filter#filter
#    - pre porovnávanie faktorov/stringov môžete použiť %in% operator - NázovPremennej %in% "HodnotaPremennej"
#    - operátory v R - https://www.statmethods.net/management/operators.html
#    - priraďte output do premennej `data_chosen`

# %%
# TODO

data_chosen <- data %>% 
    select(YearStart, YearEnd, starts_with("Location"), DataSource, TopicID, Topic, QuestionID, Question, starts_with("DataValue"), LowConfidenceLimit,
           HighConfidenceLimit, StratificationCategoryID1, StratificationID1, StratificationCategory1, Stratification1,
           -DatavalueFootnote, -DataValueFootnoteSymbol) %>%
    filter(TopicID %in% "DIA" & YearStart > 2015)

# %% [markdown]
# 5. Odstránenie chýbajúcich hodnôt
#
#     - dôležité najmä pre numerické premenné - použitie matematických funkcií

# %%
# numeric variable with non-numeric datatype
mean(data_chosen$DataValue)
# Out:
# Warning message in mean.default(data_chosen$DataValue):
# "argument is not numeric or logical: returning NA"
# [1] NA

# %%
# numeric variable with numeric datatype but also NA's
mean(data_chosen$DataValueAlt)
# Out:
# [1] NA

# %%
# numeric variable with numeric datatype but also NA's
mean(data_chosen$DataValueAlt, na.rm = TRUE)

data_chosen

# %% [markdown]
# 6. Zobrazenie nekompletných záznamov

# %%
# the dot passes the input of the filter function as an input to the complete.cases function
data_chosen %>% 
    filter(!complete.cases(.))
# Out:
#       YearStart YearEnd LocationAbbr LocationDesc   LocationID DataSource
# 1     2018      2018    SC           South Carolina 45         NVSS
# 2     2018      2018    VT           Vermont        50         NVSS
# 3     2016      2016    AL           Alabama         1         NVSS
# 4     2017      2017    AL           Alabama         1         NVSS
# 5     2017      2017    AZ           Arizona         4         NVSS
# 6     2017      2017    IA           Iowa           19         NVSS
# 7     2020      2020    LA           Louisiana      22         NVSS
# 8     2017      2017    UT           Utah           49         NVSS
# 9     2017      2017    FL           Florida        12         SEDD; SID
# 10    2017      2017    LA           Louisiana      22         SEDD; SID
# 11    2018      2018    NV           Nevada         32         SEDD; SID
# 12    2016      2016    VA           Virginia       51         SEDD; SID
# 13    2016      2016    GU           Guam           66         SEDD; SID
# 14    2018      2018    ID           Idaho          16         SEDD; SID
# 15    2016      2016    MS           Mississippi    28         SEDD; SID
# 16    2018      2018    NJ           New Jersey     34         SEDD; SID
# 17    2018      2018    OH           Ohio           39         SEDD; SID
# 18    2018      2018    WA           Washington     53         SEDD; SID
# 19    2018      2018    WI           Wisconsin      55         SEDD; SID
# 20    2020      2020    US           United States  59         NVSS
# 21    2019      2019    AK           Alaska          2         NVSS
# 22    2018      2018    ME           Maine          23         NVSS
# 23    2018      2018    NH           New Hampshire  33         NVSS
# 24    2018      2018    PA           Pennsylvania   42         NVSS
# 25    2019      2019    NM           New Mexico     35         NVSS
# 26    2016      2016    NE           Nebraska       31         NVSS
# 27    2019      2019    RI           Rhode Island   44         NVSS
# 28    2016      2016    TN           Tennessee      47         NVSS
# 29    2018      2018    FL           Florida        12         NVSS
# 30    2018      2018    DE           Delaware       10         NVSS
# ⋮     ⋮         ⋮       ⋮            ⋮              ⋮          ⋮
# 35327 2021      2021    SC           South Carolina 45         BRFSS
# 35328 2016      2016    RI           Rhode Island   44         BRFSS
# 35329 2017      2017    RI           Rhode Island   44         BRFSS
# 35330 2018      2018    RI           Rhode Island   44         BRFSS
# 35331 2017      2017    RI           Rhode Island   44         BRFSS
# 35332 2020      2020    RI           Rhode Island   44         BRFSS
# 35333 2021      2021    RI           Rhode Island   44         BRFSS
# 35334 2021      2021    SC           South Carolina 45         BRFSS
# 35335 2016      2016    RI           Rhode Island   44         BRFSS
# 35336 2016      2016    RI           Rhode Island   44         BRFSS
# 35337 2021      2021    SC           South Carolina 45         BRFSS
# 35338 2018      2018    RI           Rhode Island   44         BRFSS
# 35339 2019      2019    RI           Rhode Island   44         BRFSS
# 35340 2021      2021    RI           Rhode Island   44         BRFSS
# 35341 2020      2020    RI           Rhode Island   44         BRFSS
# 35342 2021      2021    RI           Rhode Island   44         BRFSS
# 35343 2019      2019    RI           Rhode Island   44         BRFSS
# 35344 2021      2021    SC           South Carolina 45         BRFSS
# 35345 2016      2016    RI           Rhode Island   44         BRFSS
# 35346 2020      2020    RI           Rhode Island   44         BRFSS
# 35347 2016      2016    RI           Rhode Island   44         BRFSS
# 35348 2021      2021    SC           South Carolina 45         BRFSS
# 35349 2021      2021    RI           Rhode Island   44         BRFSS
# 35350 2021      2021    SC           South Carolina 45         BRFSS
# 35351 2021      2021    RI           Rhode Island   44         BRFSS
# 35352 2020      2020    RI           Rhode Island   44         BRFSS
# 35353 2021      2021    RI           Rhode Island   44         BRFSS
# 35354 2020      2020    RI           Rhode Island   44         BRFSS
# 35355 2016      2016    RI           Rhode Island   44         BRFSS
# 35356 2019      2019    RI           Rhode Island   44         BRFSS
#       TopicID Topic    QuestionID
# 1     DIA     Diabetes DIA1_1
# 2     DIA     Diabetes DIA1_1
# 3     DIA     Diabetes DIA1_2
# 4     DIA     Diabetes DIA1_2
# 5     DIA     Diabetes DIA1_2
# 6     DIA     Diabetes DIA1_2
# 7     DIA     Diabetes DIA1_2
# 8     DIA     Diabetes DIA1_2
# 9     DIA     Diabetes DIA4_0
# 10    DIA     Diabetes DIA4_0
# 11    DIA     Diabetes DIA4_0
# 12    DIA     Diabetes DIA4_0
# 13    DIA     Diabetes DIA9_0
# 14    DIA     Diabetes DIA9_0
# 15    DIA     Diabetes DIA9_0
# 16    DIA     Diabetes DIA9_0
# 17    DIA     Diabetes DIA9_0
# 18    DIA     Diabetes DIA9_0
# 19    DIA     Diabetes DIA9_0
# 20    DIA     Diabetes DIA1_2
# 21    DIA     Diabetes DIA1_1
# 22    DIA     Diabetes DIA1_1
# 23    DIA     Diabetes DIA1_1
# 24    DIA     Diabetes DIA1_1
# 25    DIA     Diabetes DIA1_1
# 26    DIA     Diabetes DIA1_1
# 27    DIA     Diabetes DIA1_1
# 28    DIA     Diabetes DIA1_1
# 29    DIA     Diabetes DIA1_1
# 30    DIA     Diabetes DIA1_1
# ⋮     ⋮       ⋮        ⋮
# 35327 DIA     Diabetes DIA13_2
# 35328 DIA     Diabetes DIA12_2
# 35329 DIA     Diabetes DIA13_1
# 35330 DIA     Diabetes DIA8_0
# 35331 DIA     Diabetes DIA7_0
# 35332 DIA     Diabetes DIA13_1
# 35333 DIA     Diabetes DIA10_0
# 35334 DIA     Diabetes DIA10_0
# 35335 DIA     Diabetes DIA11_3
# 35336 DIA     Diabetes DIA13_2
# 35337 DIA     Diabetes DIA5_0
# 35338 DIA     Diabetes DIA8_0
# 35339 DIA     Diabetes DIA13_2
# 35340 DIA     Diabetes DIA7_0
# 35341 DIA     Diabetes DIA12_2
# 35342 DIA     Diabetes DIA11_2
# 35343 DIA     Diabetes DIA11_1
# 35344 DIA     Diabetes DIA7_0
# 35345 DIA     Diabetes DIA10_0
# 35346 DIA     Diabetes DIA7_0
# 35347 DIA     Diabetes DIA7_0
# 35348 DIA     Diabetes DIA6_0
# 35349 DIA     Diabetes DIA10_0
# 35350 DIA     Diabetes DIA10_0
# 35351 DIA     Diabetes DIA6_0
# 35352 DIA     Diabetes DIA10_0
# 35353 DIA     Diabetes DIA6_0
# 35354 DIA     Diabetes DIA8_0
# 35355 DIA     Diabetes DIA13_2
# 35356 DIA     Diabetes DIA13_2
#       Question
# 1     Mortality due to diabetes reported as any listed cause of death
# 2     Mortality due to diabetes reported as any listed cause of death
# 3     Mortality with diabetic ketoacidosis reported as any listed cause of death
# 4     Mortality with diabetic ketoacidosis reported as any listed cause of death
# 5     Mortality with diabetic ketoacidosis reported as any listed cause of death
# 6     Mortality with diabetic ketoacidosis reported as any listed cause of death
# 7     Mortality with diabetic ketoacidosis reported as any listed cause of death
# 8     Mortality with diabetic ketoacidosis reported as any listed cause of death
# 9     Amputation of a lower extremity attributable to diabetes
# 10    Amputation of a lower extremity attributable to diabetes
# 11    Amputation of a lower extremity attributable to diabetes
# 12    Amputation of a lower extremity attributable to diabetes
# 13    Hospitalization with diabetes as a listed diagnosis
# 14    Hospitalization with diabetes as a listed diagnosis
# 15    Hospitalization with diabetes as a listed diagnosis
# 16    Hospitalization with diabetes as a listed diagnosis
# 17    Hospitalization with diabetes as a listed diagnosis
# 18    Hospitalization with diabetes as a listed diagnosis
# 19    Hospitalization with diabetes as a listed diagnosis
# 20    Mortality with diabetic ketoacidosis reported as any listed cause of death
# 21    Mortality due to diabetes reported as any listed cause of death
# 22    Mortality due to diabetes reported as any listed cause of death
# 23    Mortality due to diabetes reported as any listed cause of death
# 24    Mortality due to diabetes reported as any listed cause of death
# 25    Mortality due to diabetes reported as any listed cause of death
# 26    Mortality due to diabetes reported as any listed cause of death
# 27    Mortality due to diabetes reported as any listed cause of death
# 28    Mortality due to diabetes reported as any listed cause of death
# 29    Mortality due to diabetes reported as any listed cause of death
# 30    Mortality due to diabetes reported as any listed cause of death
# ⋮     ⋮
# 35327 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 35328 Influenza vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 35329 Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes
# 35330 Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes
# 35331 Dilated eye examination among adults aged >= 18 years with diagnosed diabetes
# 35332 Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes
# 35333 Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course
# 35334 Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course
# 35335 Prevalence of depressive disorders among adults aged >= 18 years with diagnosed diabetes
# 35336 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 35337 Foot examination among adults aged >= 18 years with diagnosed diabetes
# 35338 Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes
# 35339 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 35340 Dilated eye examination among adults aged >= 18 years with diagnosed diabetes
# 35341 Influenza vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 35342 Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes
# 35343 Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes
# 35344 Dilated eye examination among adults aged >= 18 years with diagnosed diabetes
# 35345 Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course
# 35346 Dilated eye examination among adults aged >= 18 years with diagnosed diabetes
# 35347 Dilated eye examination among adults aged >= 18 years with diagnosed diabetes
# 35348 Glycosylated hemoglobin measurement among adults aged >= 18 years with diagnosed diabetes
# 35349 Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course
# 35350 Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course
# 35351 Glycosylated hemoglobin measurement among adults aged >= 18 years with diagnosed diabetes
# 35352 Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course
# 35353 Glycosylated hemoglobin measurement among adults aged >= 18 years with diagnosed diabetes
# 35354 Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes
# 35355 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
# 35356 Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes
#       ⋯ DataValueType           DataValue DataValueAlt DataValueTypeID
# 1     ⋯ Number                  2657        2657       NMBR
# 2     ⋯ Number                  329          329       NMBR
# 3     ⋯ Number                  58            58       NMBR
# 4     ⋯ Number                  51            51       NMBR
# 5     ⋯ Number                  118          118       NMBR
# 6     ⋯ Number                  55            55       NMBR
# 7     ⋯ Number                  55            55       NMBR
# 8     ⋯ Number                  31            31       NMBR
# 9     ⋯ Number                  2317        2317       NMBR
# 10    ⋯ Number                                NA       NMBR
# 11    ⋯ Number                  1081        1081       NMBR
# 12    ⋯ Number                                NA       NMBR
# 13    ⋯ Number                                NA       NMBR
# 14    ⋯ Number                                NA       NMBR
# 15    ⋯ Number                  40353      40353       NMBR
# 16    ⋯ Number                  30025      30025       NMBR
# 17    ⋯ Number                                NA       NMBR
# 18    ⋯ Number                  66866      66866       NMBR
# 19    ⋯ Number                  126046    126046       NMBR
# 20    ⋯ Number                  8342        8342       NMBR
# 21    ⋯ Crude Rate                            NA       CRDRATE
# 22    ⋯ Number                                NA       NMBR
# 23    ⋯ Crude Rate                            NA       CRDRATE
# 24    ⋯ Number                  1178        1178       NMBR
# 25    ⋯ Number                  866          866       NMBR
# 26    ⋯ Number                  955          955       NMBR
# 27    ⋯ Number                  420          420       NMBR
# 28    ⋯ Number                  46            46       NMBR
# 29    ⋯ Number                  205          205       NMBR
# 30    ⋯ Number                  752          752       NMBR
# ⋮     ⋱ ⋮                       ⋮         ⋮            ⋮
# 35327 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35328 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35329 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35330 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35331 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35332 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35333 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35334 ⋯ Crude Prevalence                  NA           CRDPREV
# 35335 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35336 ⋯ Crude Prevalence                  NA           CRDPREV
# 35337 ⋯ Crude Prevalence                  NA           CRDPREV
# 35338 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35339 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35340 ⋯ Crude Prevalence                  NA           CRDPREV
# 35341 ⋯ Crude Prevalence                  NA           CRDPREV
# 35342 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35343 ⋯ Crude Prevalence                  NA           CRDPREV
# 35344 ⋯ Crude Prevalence                  NA           CRDPREV
# 35345 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35346 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35347 ⋯ Crude Prevalence                  NA           CRDPREV
# 35348 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35349 ⋯ Crude Prevalence                  NA           CRDPREV
# 35350 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35351 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
# 35352 ⋯ Crude Prevalence                  NA           CRDPREV
# 35353 ⋯ Crude Prevalence                  NA           CRDPREV
# 35354 ⋯ Crude Prevalence                  NA           CRDPREV
# 35355 ⋯ Crude Prevalence                  NA           CRDPREV
# 35356 ⋯ Age-adjusted Prevalence           NA           AGEADJPREV
#       LowConfidenceLimit HighConfidenceLimit StratificationCategoryID1
# 1     NA                 NA                  GENDER
# 2     NA                 NA                  GENDER
# 3     NA                 NA                  GENDER
# 4     NA                 NA                  GENDER
# 5     NA                 NA                  OVERALL
# 6     NA                 NA                  OVERALL
# 7     NA                 NA                  GENDER
# 8     NA                 NA                  OVERALL
# 9     NA                 NA                  RACE
# 10    NA                 NA                  GENDER
# 11    NA                 NA                  OVERALL
# 12    NA                 NA                  GENDER
# 13    NA                 NA                  GENDER
# 14    NA                 NA                  GENDER
# 15    NA                 NA                  GENDER
# 16    NA                 NA                  RACE
# 17    NA                 NA                  OVERALL
# 18    NA                 NA                  GENDER
# 19    NA                 NA                  OVERALL
# 20    NA                 NA                  OVERALL
# 21    NA                 NA                  RACE
# 22    NA                 NA                  RACE
# 23    NA                 NA                  RACE
# 24    NA                 NA                  RACE
# 25    NA                 NA                  GENDER
# 26    NA                 NA                  GENDER
# 27    NA                 NA                  GENDER
# 28    NA                 NA                  RACE
# 29    NA                 NA                  RACE
# 30    NA                 NA                  OVERALL
# ⋮     ⋮                  ⋮                   ⋮
# 35327 NA                 NA                  RACE
# 35328 NA                 NA                  RACE
# 35329 NA                 NA                  RACE
# 35330 NA                 NA                  RACE
# 35331 NA                 NA                  RACE
# 35332 NA                 NA                  RACE
# 35333 NA                 NA                  RACE
# 35334 NA                 NA                  GENDER
# 35335 NA                 NA                  RACE
# 35336 NA                 NA                  RACE
# 35337 NA                 NA                  RACE
# 35338 NA                 NA                  RACE
# 35339 NA                 NA                  RACE
# 35340 NA                 NA                  RACE
# 35341 NA                 NA                  RACE
# 35342 NA                 NA                  RACE
# 35343 NA                 NA                  RACE
# 35344 NA                 NA                  RACE
# 35345 NA                 NA                  GENDER
# 35346 NA                 NA                  RACE
# 35347 NA                 NA                  RACE
# 35348 NA                 NA                  RACE
# 35349 NA                 NA                  GENDER
# 35350 NA                 NA                  OVERALL
# 35351 NA                 NA                  RACE
# 35352 NA                 NA                  RACE
# 35353 NA                 NA                  OVERALL
# 35354 NA                 NA                  RACE
# 35355 NA                 NA                  RACE
# 35356 NA                 NA                  RACE
#       StratificationID1 StratificationCategory1 Stratification1
# 1     GENM              Gender                  Male
# 2     GENF              Gender                  Female
# 3     GENM              Gender                  Male
# 4     GENM              Gender                  Male
# 5     OVR               Overall                 Overall
# 6     OVR               Overall                 Overall
# 7     GENM              Gender                  Male
# 8     OVR               Overall                 Overall
# 9     BLK               Race/Ethnicity          Black, non-Hispanic
# 10    GENM              Gender                  Male
# 11    OVR               Overall                 Overall
# 12    GENM              Gender                  Male
# 13    GENM              Gender                  Male
# 14    GENM              Gender                  Male
# 15    GENM              Gender                  Male
# 16    HIS               Race/Ethnicity          Hispanic
# 17    OVR               Overall                 Overall
# 18    GENM              Gender                  Male
# 19    OVR               Overall                 Overall
# 20    OVR               Overall                 Overall
# 21    HIS               Race/Ethnicity          Hispanic
# 22    BLK               Race/Ethnicity          Black, non-Hispanic
# 23    HIS               Race/Ethnicity          Hispanic
# 24    BLK               Race/Ethnicity          Black, non-Hispanic
# 25    GENF              Gender                  Female
# 26    GENM              Gender                  Male
# 27    GENF              Gender                  Female
# 28    HIS               Race/Ethnicity          Hispanic
# 29    API               Race/Ethnicity          Asian or Pacific Islander
# 30    OVR               Overall                 Overall
# ⋮     ⋮                 ⋮                       ⋮
# 35327 OTH               Race/Ethnicity          Other, non-Hispanic
# 35328 OTH               Race/Ethnicity          Other, non-Hispanic
# 35329 OTH               Race/Ethnicity          Other, non-Hispanic
# 35330 OTH               Race/Ethnicity          Other, non-Hispanic
# 35331 OTH               Race/Ethnicity          Other, non-Hispanic
# 35332 OTH               Race/Ethnicity          Other, non-Hispanic
# 35333 OTH               Race/Ethnicity          Other, non-Hispanic
# 35334 GENM              Gender                  Male
# 35335 BLK               Race/Ethnicity          Black, non-Hispanic
# 35336 OTH               Race/Ethnicity          Other, non-Hispanic
# 35337 BLK               Race/Ethnicity          Black, non-Hispanic
# 35338 BLK               Race/Ethnicity          Black, non-Hispanic
# 35339 MRC               Race/Ethnicity          Multiracial, non-Hispanic
# 35340 BLK               Race/Ethnicity          Black, non-Hispanic
# 35341 OTH               Race/Ethnicity          Other, non-Hispanic
# 35342 BLK               Race/Ethnicity          Black, non-Hispanic
# 35343 BLK               Race/Ethnicity          Black, non-Hispanic
# 35344 BLK               Race/Ethnicity          Black, non-Hispanic
# 35345 GENF              Gender                  Female
# 35346 WHT               Race/Ethnicity          White, non-Hispanic
# 35347 MRC               Race/Ethnicity          Multiracial, non-Hispanic
# 35348 BLK               Race/Ethnicity          Black, non-Hispanic
# 35349 GENM              Gender                  Male
# 35350 OVR               Overall                 Overall
# 35351 WHT               Race/Ethnicity          White, non-Hispanic
# 35352 BLK               Race/Ethnicity          Black, non-Hispanic
# 35353 OVR               Overall                 Overall
# 35354 BLK               Race/Ethnicity          Black, non-Hispanic
# 35355 MRC               Race/Ethnicity          Multiracial, non-Hispanic
# 35356 OTH               Race/Ethnicity          Other, non-Hispanic

# %% [markdown]
# Vymazanie záznamov, ktoré majú v stĺpci DataValueAlt hodnotu NA

# %%
data_filtered <- data_chosen %>% 
    drop_na(DataValueAlt)

data_filtered

# %% [markdown]
# Overenie, či dataset obsahuje ešte nejaké NA hodnoty:

# %%
# TODO
summary(data_filtered)
# Out:
# Error in eval(expr, envir, enclos): object 'data_filtered' not found
# Traceback:
#
# 1. summary(data_filtered)

# %% [markdown]
# 7. Odstránenie duplicitných hodnôt
#
#     - funkcia distinct - https://www.rdocumentation.org/packages/dplyr/versions/1.0.10/topics/distinct

# %%
data_clean <- data_filtered %>% 
    distinct()

data_clean
# Out:
# Error in eval(expr, envir, enclos): object 'data_filtered' not found
# Traceback:

# %% [markdown]
# ## Úpravy (mutate)
#
# - ak z nejakých dôvodov potrebujeme urobiť zmeny premenných
#     - prekódovanie premennej
#     - zmena názvu premennej
#     - vytvorenie pivotovej tabuľky a pod.

# %% [markdown]
# 1. Prekódovanie hodnôt
#
#    - napr. ak chceme niektorú z kategorických premenných označiť číselným kódovaním, prípadne zmeniť ich poradie, atď.

# %%
unique(data_clean$Stratification1)
unique(data_clean$StratificationID1)

# %% [markdown]
# Aký dátový typ má premenná `Stratification1` ?

# %%
class(data_clean$Stratification1)

# %% [markdown]
# Aky typ musí mať aby bola kategorická?
#
# Zmeňte typ premennej `StratificationID1` na kategorický a nastavte poradie hodnôt v tejto premennej.
#
# - Použite funkciu factor - https://www.rdocumentation.org/packages/base/versions/3.6.2/topics/factor

# %%
data_clean$StratificationID1 <- factor(data_clean$StratificationID1, levels = c('GENF','GENM','OVR','BLK','HIS','API','WHT','AIAN'))

# %% [markdown]
# Vytvorte v datasete `data_clean` novú premennú s názvom `Stratification1ID_code`, ktorá bude obsahovať zakódované hodnoty premennej  `Stratification1ID` vo forme celých čísel.
# - Použite funkciu as.integer - https://www.rdocumentation.org/packages/base/versions/3.6.2/topics/integer

# %%
data_clean$StratificationID1 <- as.integer(data_clean$StratificationID1)

data_clean

# %% [markdown]
# 2. Zmena názvu premennej
# - funkcia rename - https://dplyr.tidyverse.org/reference/rename.html

# %%
data_clean <- data_clean %>%
    rename("DataValueNum" = "DataValueAlt")  # target = source

data_clean

# %% [markdown]
# 3. Vytvorenie kontingenčnej tabuľky (pivot table)
#
#    - vzájomný vzťah dvoch premenných
#    - stĺpce ukazujú hodnoty jednej premennej, riadky druhej premennej
#    - hodnoty v tabuľke ukazujú agregované hodnoty - počet, maximum, minimum, priemer, ..
#
# Na vytvorenie sa môže použiť funkcia pivot_wider alebo pivot_longer

# %%
# select specific data for pivot table only
data_pivot <- select(data_clean, YearStart, LocationAbbr, DataValueNum) 

# pivot table in wider format where columns are YearStart values, 
# rows are LocationAbbr and values are the mean of DataValueAlt
pivot_table <- data_pivot %>%
    pivot_wider(names_from = YearStart, 
                values_from = DataValueNum, 
                values_fn = list(DataValueNum = mean))

pivot_table

# %% [markdown]
# ## Popis (describe)
#
# - popis intervalu, v ktorom sa údaje nachádzajú
# - ich sústredenie (centralizovanie) okolo stredu
# - rozptyl
# - sumarizácia
# - vytvorenie tabuliek

# %% [markdown]
# 1. Popis matematických vlastností

# %%
min(data_clean$DataValueNum)
max(data_clean$DataValueNum)

# min - max
range(data_clean$DataValueNum)

# interquartile range
IQR(data_clean$DataValueNum)

mean(data_clean$DataValueNum, na.rm = TRUE)
median(data_clean$DataValueNum)

var(data_clean$DataValueNum)

# %% [markdown]
# 2. Vytvorenie tabuľky s použitím sumarizácie
#
#    - zoskupovanie údajov - funkcia group_by - https://dplyr.tidyverse.org/reference/group_by.html
#    - funkcia summarise - https://dplyr.tidyverse.org/reference/summarise.html

# %%
data_clean %>%
    group_by(LocationAbbr) %>%
    summarise(MinValue = min(DataValueNum), 
              MaxValue = max(DataValueNum), 
              Mean = mean(DataValueNum),
              SD = sd(DataValueNum))

# %% [markdown]
# ## Vizualizácia (vizualize)
#
# - grafy pre jednoduché pochopenie údajov
# - oddelenie kategorickej závislej premennej v priestore nezávislých premenných
#     - napr. farebné oddelenie chorých/zdravých pacientov v grafe priemerných hodnôt krvného tlaku a veku
#
# + najpoužívanejšia knižnica - ggplot2 - https://ggplot2.tidyverse.org/

# %% [markdown]
# 1. Stĺpcový graf Výskytu cukrovky podľa lokality

# %%
ggplot(data_clean, aes(x = LocationAbbr, y = DataValueNum)) +
  geom_col() +
  theme(axis.text.x = element_text(angle = 90)) +
  labs(title = "Prevalence of Diabetes by Location", y = "Prevalence", x = "Location")

# %% [markdown]
# 6. Boxplot diagram
#
#    - čiara - medián
#    - box - medzikvartilové rozpätie - obsahuje 50% hodnôt
#    - hranice - minimum, maximum

# %%
subdata_questions <- select(data_clean, Question, QuestionID)

View(unique(subdata_questions))

# %%
data_chosen <- data %>% 
    select(YearStart, YearEnd, starts_with("Location"), DataSource, TopicID, Topic, QuestionID, Question, starts_with("DataValue"), LowConfidenceLimit,
           HighConfidenceLimit, StratificationCategoryID1, StratificationID1, StratificationCategory1, Stratification1,
           -DatavalueFootnote, -DataValueFootnoteSymbol)
data_chosen

# influenza Vaccination Rate by Gender (question DIA12_1)
# Influenza vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes
vaccination_data <- data_chosen %>% 
  filter(QuestionID == "DIA9_0") %>%
  mutate(Stratification1 = as.factor(Stratification1)) # ensure Stratification1 is a factor

ggplot(vaccination_data, aes(x = Stratification1, y = DataValueAlt)) +
  geom_boxplot() +
  theme(axis.text.x = element_text(angle = 50)) +
  labs(title = "Influenza Vaccination Rate by Gender", y = "Vaccination Rate (%)", x = "Gender")

# %% [markdown]
# Pozorovania:
#
# - Medián zaočkovanosti je vo všetkých skupinách v intervale 40-60 %.
# - Medzikvartilové rozpätie (IQR - box) je vo väčšine skupín podobné, čo naznačuje konzistentné rozloženie údajov okolo mediánu.
# - Najmenšia vaeriabilita je v skupine "Multiracial, non-Hispanic".
# - V niekoľkých skupinách sa vyskytujú odľahlé hodnoty, najmä v skupinách "Black, non-Hispanic, Male a Overall", čo poukazuje na niektoré osoby s výrazne nižšou mierou zaočkovanosti.

# %% [markdown]
# ## Analýza (analyze)

# %% [markdown]
# - Odhalenie závislostí (napr. korelácia)
# - Štatistické testy
# - Algoritmy (dimenzionálna redukcia, strojové učenie, ...)

# %% [markdown]
# Dataset Breast Cancer Wisconsin (Original)
#
# - dostupný na https://archive.ics.uci.edu/dataset/15/breast+cancer+wisconsin+original
#
# - premenné:
#     - Sample_code_number (ID),
#     - Clump_thickness - hrúbka zhluku
#     - Uniformity_of_cell_size - Uniformita veľkosti buniek
#     - Uniformity_of_cell_shape - uniformita tvaru buniek
#     - Marginal_adhesion - Priľnavosť okrajov
#     - Single_epithelial_cell_size - veľkosť jednej epitelovej bunky
#     - Bare_nuclei - "holé" jadrá (bez cytoplazmy)
#     - Bland_chromatin - nevýrazný chromatín
#     - Normal_nucleoli - normálne jadrá
#     - Mitoses - mitózy
#     - Class - typ nádoru (4 Malígny, 2 Benígny)

# %%
# load the dataset
url <- "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data"

# change the variable names
data_bc <- read.csv(file = url, header = FALSE,
                col.names = c("id","CT", "UCSize", "UCShape", "MA", "SECS", "BN", "BC", "NN","M", "diagnosis"))
head(data_bc)

# mutate the diagnosis variable
data_bc$diagnosis[data_bc$diagnosis==4] = 1 # malign
data_bc$diagnosis[data_bc$diagnosis==2] = 0 # benign

#filter to check and review any duplicate records
data_bc <- data_bc %>% 
    distinct()

# select only relevant variables
data_bc <- data_bc %>% select(-id, -BN)

head(data_bc)

# %% [markdown]
# 1. Vzťahy medzi premennými
#
#    - premenné sa môžu navzájom ovplyvňovať
#    - lineárne alebo nelineárne vzťahy
#    - vizualizácia pre jednoduché pochopenie, či je možné pomocou vybraných premenných jednoznačne oddeliť hodnoty závislej premennej (v tomto prípade benígne a malígne nádory)

# %%
ggplot(data_bc, aes(x = M, y = BC, color = diagnosis)) +
  geom_point() +
  ggtitle("Scatter Plot of M vs BC")

# %%
ggplot(data_bc, aes(x = UCSize, y = UCShape, color = diagnosis)) +
  geom_point() +
  ggtitle("Scatter Plot of UCSize vs UCShape")

# %% [markdown]
# 2. Korelácia premenných
#
#     - V intervale <-1, 1>
#     - pozitívna (1) - so zvyšovaním jednej premennej sa zvyšuje aj druhá
#     - negatívna (-1) - so zvyšovaním jednej premennej sa druhá premenná znižuje
#     - nulová (0) - premenné sa neovplyvňujú
#
#
#    Korelácia neznamená kauzalitu - dva javy sa môžu ukazovať ako závislé, ale neznamená to, že jeden spôsobuje vznik druhého.

# %%
library(corrplot)

# create a correlation matrix
data_bc_matrix <- cor(data_bc)

# create a correlation plot
corrplot(data_bc_matrix, order="hclust", type='upper',tl.srt = 45, tl.cex = 0.6)
